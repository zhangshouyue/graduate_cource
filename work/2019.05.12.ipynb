# %%
from astropy.io import fits
import matplotlib.pyplot as plt
'''
# %matplotlib inline
import matplotlib
from IPython.core.pylabtools import figsize
'''
import numpy as np

# %%
folder = '/home/zkc/桌面/90Star catalogue/'
doc1 = 'Z_Qfl=AAA_132 2mass.fits'
doc2 = 'Z_Qfl=AAA_151687 2mass.fits'

# %%
hdu = fits.open(folder+doc1)
hdu1 = fits.open(folder+doc2)
data = hdu[1].data
data1 = hdu[1].data

# %%
hdu.info()
# Out:
# Filename: /home/zkc/桌面/90Star catalogue/Z_Qfl=AAA_132 2mass.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
# ...

# %%
hdu[1].data.names
# Out:
# ['solution_id',
#  'designation_1',
#  'source_id',
#  'random_index',
#  'ref_epoch',
#  'ra_1',
#  'ra_error_1',
#  'dec_1',
#  'dec_error_1',
#  'parallax_1',
#  'parallax_error_1',
#  'parallax_over_error',
#  'pmra_1',
#  'pmra_error_1',
#  'pmdec_1',
#  'pmdec_error_1',
#  'ra_dec_corr',
#  'ra_parallax_corr',
#  'ra_pmra_corr',
#  'ra_pmdec_corr',
#  'dec_parallax_corr',
#  'dec_pmra_corr',
#  'dec_pmdec_corr',
#  'parallax_pmra_corr',
#  'parallax_pmdec_corr',
#  'pmra_pmdec_corr',
#  'astrometric_n_obs_al',
#  'astrometric_n_obs_ac',
#  'astrometric_n_good_obs_al',
#  'astrometric_n_bad_obs_al',
#  'astrometric_gof_al',
#  'astrometric_chi2_al',
#  'astrometric_excess_noise',
#  'astrometric_excess_noise_sig',
#  'astrometric_params_solved',
#  'astrometric_primary_flag',
#  'astrometric_weight_al',
#  'astrometric_pseudo_colour',
#  'astrometric_pseudo_colour_error',
#  'mean_varpi_factor_al',
#  'astrometric_matched_observations',
#  'visibility_periods_used',
# ...

# %%
hdu[1].columns.names
# Out:
# ['solution_id',
#  'designation_1',
#  'source_id',
#  'random_index',
#  'ref_epoch',
#  'ra_1',
#  'ra_error_1',
#  'dec_1',
#  'dec_error_1',
#  'parallax_1',
#  'parallax_error_1',
#  'parallax_over_error',
#  'pmra_1',
#  'pmra_error_1',
#  'pmdec_1',
#  'pmdec_error_1',
#  'ra_dec_corr',
#  'ra_parallax_corr',
#  'ra_pmra_corr',
#  'ra_pmdec_corr',
#  'dec_parallax_corr',
#  'dec_pmra_corr',
#  'dec_pmdec_corr',
#  'parallax_pmra_corr',
#  'parallax_pmdec_corr',
#  'pmra_pmdec_corr',
#  'astrometric_n_obs_al',
#  'astrometric_n_obs_ac',
#  'astrometric_n_good_obs_al',
#  'astrometric_n_bad_obs_al',
#  'astrometric_gof_al',
#  'astrometric_chi2_al',
#  'astrometric_excess_noise',
#  'astrometric_excess_noise_sig',
#  'astrometric_params_solved',
#  'astrometric_primary_flag',
#  'astrometric_weight_al',
#  'astrometric_pseudo_colour',
#  'astrometric_pseudo_colour_error',
#  'mean_varpi_factor_al',
#  'astrometric_matched_observations',
#  'visibility_periods_used',
# ...

# %%
hdu1.info()
# Out:
# Filename: /home/zkc/桌面/90Star catalogue/Z_Qfl=AAA_151687 2mass.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1                1 BinTableHDU    234   35030R x 113C   [K, 28A, K, K, D, D, D, D, D, D, D, E, D, D, D, D, E, E, E, E, E, E, E, E, E, E, J, J, J, J, E, E, D, D, I, L, E, D, D, E, I, I, E, J, I, L, J, D, D, E, E, J, D, D, E, E, J, D, D, E, E, E, I, E, E, E, D, D, J, E, E, E, 13A, D, D, D, D, K, E, E, E, E, E, E, E, E, E, K, E, E, E, E, E, E, 77A, 99A, 17A, D, D, E, E, E, E, E, E, E, E, E, 3A, I, B, D, D]

# %%
hdu1[1].data.names
# Out:
# ['solution_id',
#  'designation',
#  'source_id',
#  'random_index',
#  'ref_epoch',
#  'ra',
#  'ra_error',
#  'dec',
#  'dec_error',
#  'parallax',
#  'parallax_error',
#  'parallax_over_error',
#  'pmra',
#  'pmra_error',
#  'pmdec',
#  'pmdec_error',
#  'ra_dec_corr',
#  'ra_parallax_corr',
#  'ra_pmra_corr',
#  'ra_pmdec_corr',
#  'dec_parallax_corr',
#  'dec_pmra_corr',
#  'dec_pmdec_corr',
#  'parallax_pmra_corr',
#  'parallax_pmdec_corr',
#  'pmra_pmdec_corr',
#  'astrometric_n_obs_al',
#  'astrometric_n_obs_ac',
#  'astrometric_n_good_obs_al',
#  'astrometric_n_bad_obs_al',
#  'astrometric_gof_al',
#  'astrometric_chi2_al',
#  'astrometric_excess_noise',
#  'astrometric_excess_noise_sig',
#  'astrometric_params_solved',
#  'astrometric_primary_flag',
#  'astrometric_weight_al',
#  'astrometric_pseudo_colour',
#  'astrometric_pseudo_colour_error',
#  'mean_varpi_factor_al',
#  'astrometric_matched_observations',
#  'visibility_periods_used',
#  'astrometric_sigma5d_max',
# ...

# %%
c1=hdu[1].data
x =c1['Jmag']
y =c1['Hmag']
z =c1['Kmag']
c2=hdu1[1].data
x1 =c2['Jmag']
y1 =c2['Hmag']
z1 =c2['Kmag']

# %%
fig = plt.figure()
plt.scatter(y1-z1,x1-y1,c='tomato',label='SAMPLE',s=1)
plt.scatter(y-z,x-y,c='blue',label='OB',s=1)
plt.title('2mass',color='lime',fontsize=12)
plt.xlabel('H-K',color='crimson',fontsize=10)
plt.ylabel('J-H',color='crimson',fontsize=10)
plt.legend(loc='upper right')
x2=y-z
y2=1.688*x2
plt.plot(x2,y2,color='yellow',linewidth=1)
#figsize(4,4)
x3=y-z
y3=1.688*x3+0.2
plt.plot(x3,y3,color='g',linewidth=1)
x4=y-z
y4=1.688*x4-0.2
plt.plot(x4,y4,color='lime',linewidth=1)
'''
plt.plot([0.4,0.2],[0.5,0.75],color='k',linewidth=1)
plt.plot([-0.05,-0.05],[-0.26,0.25],color='k',linewidth=1)
plt.plot([0.35,0.35],[0.25,0.56],color='k',linewidth=1)
'''
#plt.savefig('/home/zkc/桌面/90星图/_05.13.png')
'''
   x轴：H-K-0.154ebv
   y轴：J-H-0.26ebv
   k=0.26/0.154=1.68831169
'''

x5=(0.4,0.4)
y5=(0,1)
x6=(-0.1,-0.1)
y6=(-0.25,0.25)
plt.plot(x5,y5)
plt.plot(x6,y6)
#plt.show()
plt.savefig('/home/zkc/aastexv6.2/aastexv6.2/期末/012.eps')
