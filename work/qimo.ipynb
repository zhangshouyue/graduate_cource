# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
hdu = pd.read_csv('/home/zkc/桌面/90Star catalogue/yangbenjiandaoPPMXL.csv')
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (95) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
hdu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14780 entries, 0 to 14779
# Columns: 138 entries, solution_id to angDist_x
# dtypes: bool(2), float64(107), int64(23), object(6)
# memory usage: 15.4+ MB

# %%
hdu.columns
# Out:
# Index(['solution_id', 'designation', 'source_id', 'random_index', 'ref_epoch',
#        'ra', 'ra_error', 'dec', 'dec_error', 'parallax',
#        ...
#        'epDE', 'epma', 'epmd', 'b1mag', 'b2mag', 'r1mag', 'r2mag', 'imag',
#        'fl', 'angDist_x'],
#       dtype='object', length=138)

# %%
print(hdu)
# Out:
#                solution_id                   designation            source_id  \
# 0      1635721458409799680  Gaia DR2 3425367161662313088  3425367161662313088
# 1      1635721458409799680  Gaia DR2 3425378466016487808  3425378466016487808
# 2      1635721458409799680  Gaia DR2 3425343419083525632  3425343419083525632
# 3      1635721458409799680  Gaia DR2 3425338333841993856  3425338333841993856
# 4      1635721458409799680  Gaia DR2 3425375442359558656  3425375442359558656
# 5      1635721458409799680  Gaia DR2 3425375476719292416  3425375476719292416
# 6      1635721458409799680  Gaia DR2 3425370219679032832  3425370219679032832
# 7      1635721458409799680  Gaia DR2 3425327579244033792  3425327579244033792
# 8      1635721458409799680  Gaia DR2 3425375373640082048  3425375373640082048
# 9      1635721458409799680  Gaia DR2 3425370047880268672  3425370047880268672
# 10     1635721458409799680  Gaia DR2 3425336405401464064  3425336405401464064
# ...

# %%
print(hdu.columns)
# Out:
# Index(['solution_id', 'designation', 'source_id', 'random_index', 'ref_epoch',
#        'ra', 'ra_error', 'dec', 'dec_error', 'parallax',
#        ...
#        'epDE', 'epma', 'epmd', 'b1mag', 'b2mag', 'r1mag', 'r2mag', 'imag',
#        'fl', 'angDist_x'],
#       dtype='object', length=138)

# %%
hdu
# Out:
#                solution_id                   designation            source_id  \
# 0      1635721458409799680  Gaia DR2 3425367161662313088  3425367161662313088
# 1      1635721458409799680  Gaia DR2 3425378466016487808  3425378466016487808
# 2      1635721458409799680  Gaia DR2 3425343419083525632  3425343419083525632
# 3      1635721458409799680  Gaia DR2 3425338333841993856  3425338333841993856
# 4      1635721458409799680  Gaia DR2 3425375442359558656  3425375442359558656
# 5      1635721458409799680  Gaia DR2 3425375476719292416  3425375476719292416
# 6      1635721458409799680  Gaia DR2 3425370219679032832  3425370219679032832
# 7      1635721458409799680  Gaia DR2 3425327579244033792  3425327579244033792
# 8      1635721458409799680  Gaia DR2 3425375373640082048  3425375373640082048
# 9      1635721458409799680  Gaia DR2 3425370047880268672  3425370047880268672
# 10     1635721458409799680  Gaia DR2 3425336405401464064  3425336405401464064
# ...

# %%
data = hdu
name_list = hdu.columns

# %%
a =hdu['pmRA_x']
b =hdu['pmDE']
c =hdu['Jmag']
d =hdu['Kmag']
y = d + np.log((a**2+b**2)**0.5) -10
x = c-d
'''
a1 =hdu1['pmRA']
b1 =hdu1['pmDE']
c1 =hdu1['Jmag']
d1 =hdu1['Kmag']
y1 = d1 + np.log((a1**2+b1**2)**0.5) -10
x1 = c1-d1
'''
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in log
#   """
# "\na1 =hdu1['pmRA']\nb1 =hdu1['pmDE']\nc1 =hdu1['Jmag']\nd1 =hdu1['Kmag']\ny1 = d1 + np.log((a1**2+b1**2)**0.5) -10\nx1 = c1-d1\n"

# %%
y5=30*x+1.5
y6=5*x
y7=-100*x+35

# %%
plt.scatter(x,y,c='aqua',label='SAMPLE',s=1,alpha=0.1)
plt.title('The reduced proper motion',color='y',fontsize=12)
plt.xlabel('J-K',color='crimson',fontsize=10)
plt.ylabel('H_nu',color='crimson',fontsize=10)

plt.plot(x,y5,label='y5=30*x+1.5',color='red')
plt.plot(x,y6,label='y6=5*x',color='blue')
plt.plot(x,y7,label='y7=-100*x+35',color='yellow')
plt.legend(loc='lower left')
#plt.savefig('/home/zkc/aastexv6.2/aastexv6.2/期末/013.eps')

# %%
x_index= (x>0)&(x<0.4)
y_index= (y<y5)&(y>y6)&(y<y7)
index=x_index & y_index



x_selected=x[index]
y_selected=y[index]

x_selected=[]
y_selected=[]

x_selected=np.array(x_selected)
y_selected=np.array(y_selected)
table = []
for name in name_list:
    table.append(data[name][index])
t = Table(table,names = name_list)
t.write('/home/zkc/桌面/90Star catalogue/'+'sample2'+'_'+'J-K'+'_'+'H_nu'+'_'+'06.30.01'+'.csv',format = 'csv')

# %%
mata=pd.read_csv('/home/zkc/桌面/90Star catalogue/sample2_J-K_H_nu_06.30.01.csv')

# %%
mata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1998 entries, 0 to 1997
# Columns: 138 entries, solution_id to angDist_x
# dtypes: bool(2), float64(108), int64(23), object(5)
# memory usage: 2.1+ MB

# %%
a =mata['pmRA_x']
b =mata['pmDE']
c =mata['Jmag']
d =mata['Kmag']
y = d + np.log((a**2+b**2)**0.5) -10
x = c-d

# %%
plt.scatter(x,y,c='aqua',label='SAMPLE',s=1)
plt.title('The reduced proper motion',color='y',fontsize=12)
plt.xlabel('J-K',color='crimson',fontsize=10)
plt.ylabel('H_nu',color='crimson',fontsize=10)
plt.legend(loc='upper left')
#plt.show()
#plt.savefig('/home/zkc/aastexv6.2/aastexv6.2/期末/015.eps')
